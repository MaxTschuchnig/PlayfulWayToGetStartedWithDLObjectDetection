# %%
import os
import shutil
import xml.etree.ElementTree as ET

# Paths
vallabelspath = "F:/ImagenetILSVRC/Annotations/DET/val"
valimagespath = "F:/ImagenetILSVRC/Data/DET/val"
val_output_path = "F:/ImagenetILSVRC/FilteredVal"  # Where filtered images will be saved

# Ensure output directory exists
os.makedirs(val_output_path, exist_ok=True)

# Define allowed labels
labels = {
    "n02084071": "Dog",
    "n02274259": "Butterfly",
    "n03337140": "FilingCabinet",
    "n02815834": "Beaker",
    "n03642806": "Laptop",
    "n03958227": "PlasticBag",
    "n07697537": "Hotdog",
    "n07753592": "Banana",
    "n02206856": "Bee",
    "n04557648": "WaterBottle"
}

# Iterate over all annotation files
for annotation_file in os.listdir(vallabelspath):
    if not annotation_file.endswith(".xml"):
        continue  # Skip non-XML files

    annotation_path = os.path.join(vallabelspath, annotation_file)
    
    # Parse XML
    tree = ET.parse(annotation_path)
    root = tree.getroot()

    # Extract object category (some files may contain multiple objects)
    object_elements = root.findall("./object/name")

    # Check if any object in the image belongs to our labels
    matching_objects = [obj.text for obj in object_elements if obj.text in labels]
    
    if matching_objects:  # If at least one object in the image matches our labels
        # Get corresponding image filename
        image_filename = annotation_file.replace(".xml", ".JPEG")
        image_path = os.path.join(valimagespath, image_filename)

        # Determine the label (class) of the image, use the first matching object
        image_label = matching_objects[0]
        
        # Get the label folder name (to organize images by their class)
        label_folder = labels[image_label]
        label_folder_path = os.path.join(val_output_path, label_folder)

        # Create the class folder if it doesn't exist
        os.makedirs(label_folder_path, exist_ok=True)

        # Copy the image to the corresponding label folder
        if os.path.exists(image_path):
            shutil.copy(image_path, os.path.join(label_folder_path, image_filename))
            print(f"Copied: {image_filename} ({', '.join(matching_objects)})")
        else:
            print(f"Warning: Image not found {image_path}")

        # Copy the corresponding XML file to the same folder
        shutil.copy(annotation_path, os.path.join(label_folder_path, annotation_file))
        print(f"Copied: {annotation_file} (XML)")

print("Validation dataset filtering complete!")
# Out:
# Copied: ILSVRC2012_val_00000022.JPEG (n02084071, n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00000022.xml (XML)
# Copied: ILSVRC2012_val_00000031.JPEG (n02274259)
# Copied: ILSVRC2012_val_00000031.xml (XML)
# Copied: ILSVRC2012_val_00000057.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000057.xml (XML)
# Copied: ILSVRC2012_val_00000077.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000077.xml (XML)
# Copied: ILSVRC2012_val_00000115.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000115.xml (XML)
# Copied: ILSVRC2012_val_00000132.JPEG (n03337140)
# Copied: ILSVRC2012_val_00000132.xml (XML)
# Copied: ILSVRC2012_val_00000134.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000134.xml (XML)
# Copied: ILSVRC2012_val_00000140.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000140.xml (XML)
# Copied: ILSVRC2012_val_00000141.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000141.xml (XML)
# Copied: ILSVRC2012_val_00000147.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000147.xml (XML)
# Copied: ILSVRC2012_val_00000151.JPEG (n03642806)
# Copied: ILSVRC2012_val_00000151.xml (XML)
# Copied: ILSVRC2012_val_00000174.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000174.xml (XML)
# Copied: ILSVRC2012_val_00000180.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000180.xml (XML)
# Copied: ILSVRC2012_val_00000197.JPEG (n07697537)
# Copied: ILSVRC2012_val_00000197.xml (XML)
# Copied: ILSVRC2012_val_00000203.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000203.xml (XML)
# Copied: ILSVRC2012_val_00000228.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000228.xml (XML)
# Copied: ILSVRC2012_val_00000253.JPEG (n02815834)
# Copied: ILSVRC2012_val_00000253.xml (XML)
# Copied: ILSVRC2012_val_00000263.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000263.xml (XML)
# Copied: ILSVRC2012_val_00000279.JPEG (n02084071, n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00000279.xml (XML)
# Copied: ILSVRC2012_val_00000300.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000300.xml (XML)
# Copied: ILSVRC2012_val_00000320.JPEG (n07753592, n07753592, n07753592, n07753592)
# Copied: ILSVRC2012_val_00000320.xml (XML)
# Copied: ILSVRC2012_val_00000327.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000327.xml (XML)
# Copied: ILSVRC2012_val_00000331.JPEG (n04557648, n04557648, n04557648, n04557648)
# Copied: ILSVRC2012_val_00000331.xml (XML)
# Copied: ILSVRC2012_val_00000350.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000350.xml (XML)
# Copied: ILSVRC2012_val_00000355.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000355.xml (XML)
# Copied: ILSVRC2012_val_00000379.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000379.xml (XML)
# Copied: ILSVRC2012_val_00000383.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000383.xml (XML)
# Copied: ILSVRC2012_val_00000391.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000391.xml (XML)
# Copied: ILSVRC2012_val_00000405.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000405.xml (XML)
# Copied: ILSVRC2012_val_00000407.JPEG (n02206856)
# Copied: ILSVRC2012_val_00000407.xml (XML)
# Copied: ILSVRC2012_val_00000425.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000425.xml (XML)
# Copied: ILSVRC2012_val_00000429.JPEG (n02084071, n02084071, n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00000429.xml (XML)
# Copied: ILSVRC2012_val_00000440.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000440.xml (XML)
# Copied: ILSVRC2012_val_00000462.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000462.xml (XML)
# Copied: ILSVRC2012_val_00000500.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00000500.xml (XML)
# Copied: ILSVRC2012_val_00000507.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000507.xml (XML)
# Copied: ILSVRC2012_val_00000516.JPEG (n03958227)
# Copied: ILSVRC2012_val_00000516.xml (XML)
# Copied: ILSVRC2012_val_00000524.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000524.xml (XML)
# Copied: ILSVRC2012_val_00000581.JPEG (n02274259)
# Copied: ILSVRC2012_val_00000581.xml (XML)
# Copied: ILSVRC2012_val_00000588.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00000588.xml (XML)
# Copied: ILSVRC2012_val_00000590.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000590.xml (XML)
# Copied: ILSVRC2012_val_00000594.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000594.xml (XML)
# Copied: ILSVRC2012_val_00000599.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000599.xml (XML)
# Copied: ILSVRC2012_val_00000603.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000603.xml (XML)
# Copied: ILSVRC2012_val_00000618.JPEG (n02274259)
# Copied: ILSVRC2012_val_00000618.xml (XML)
# Copied: ILSVRC2012_val_00000635.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000635.xml (XML)
# Copied: ILSVRC2012_val_00000643.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000643.xml (XML)
# Copied: ILSVRC2012_val_00000658.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000658.xml (XML)
# Copied: ILSVRC2012_val_00000660.JPEG (n04557648, n03642806, n03642806)
# Copied: ILSVRC2012_val_00000660.xml (XML)
# Copied: ILSVRC2012_val_00000668.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000668.xml (XML)
# Copied: ILSVRC2012_val_00000694.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000694.xml (XML)
# Copied: ILSVRC2012_val_00000696.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000696.xml (XML)
# Copied: ILSVRC2012_val_00000719.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000719.xml (XML)
# Copied: ILSVRC2012_val_00000722.JPEG (n03958227)
# Copied: ILSVRC2012_val_00000722.xml (XML)
# Copied: ILSVRC2012_val_00000748.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000748.xml (XML)
# Copied: ILSVRC2012_val_00000759.JPEG (n03958227, n03958227)
# Copied: ILSVRC2012_val_00000759.xml (XML)
# Copied: ILSVRC2012_val_00000799.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00000799.xml (XML)
# Copied: ILSVRC2012_val_00000800.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000800.xml (XML)
# Copied: ILSVRC2012_val_00000802.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000802.xml (XML)
# Copied: ILSVRC2012_val_00000810.JPEG (n02274259)
# Copied: ILSVRC2012_val_00000810.xml (XML)
# Copied: ILSVRC2012_val_00000811.JPEG (n07697537)
# Copied: ILSVRC2012_val_00000811.xml (XML)
# Copied: ILSVRC2012_val_00000824.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000824.xml (XML)
# Copied: ILSVRC2012_val_00000832.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000832.xml (XML)
# Copied: ILSVRC2012_val_00000875.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000875.xml (XML)
# Copied: ILSVRC2012_val_00000882.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000882.xml (XML)
# Copied: ILSVRC2012_val_00000884.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00000884.xml (XML)
# Copied: ILSVRC2012_val_00000909.JPEG (n02084071, n03958227)
# Copied: ILSVRC2012_val_00000909.xml (XML)
# Copied: ILSVRC2012_val_00000922.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00000922.xml (XML)
# Copied: ILSVRC2012_val_00000948.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00000948.xml (XML)
# Copied: ILSVRC2012_val_00000997.JPEG (n02084071)
# Copied: ILSVRC2012_val_00000997.xml (XML)
# Copied: ILSVRC2012_val_00001001.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001001.xml (XML)
# Copied: ILSVRC2012_val_00001014.JPEG (n02274259)
# Copied: ILSVRC2012_val_00001014.xml (XML)
# Copied: ILSVRC2012_val_00001015.JPEG (n02274259)
# Copied: ILSVRC2012_val_00001015.xml (XML)
# Copied: ILSVRC2012_val_00001028.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001028.xml (XML)
# Copied: ILSVRC2012_val_00001047.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001047.xml (XML)
# Copied: ILSVRC2012_val_00001049.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001049.xml (XML)
# Copied: ILSVRC2012_val_00001065.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001065.xml (XML)
# Copied: ILSVRC2012_val_00001069.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001069.xml (XML)
# Copied: ILSVRC2012_val_00001074.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001074.xml (XML)
# Copied: ILSVRC2012_val_00001096.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001096.xml (XML)
# Copied: ILSVRC2012_val_00001097.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001097.xml (XML)
# Copied: ILSVRC2012_val_00001109.JPEG (n02084071, n02084071, n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00001109.xml (XML)
# Copied: ILSVRC2012_val_00001112.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001112.xml (XML)
# Copied: ILSVRC2012_val_00001113.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001113.xml (XML)
# Copied: ILSVRC2012_val_00001123.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001123.xml (XML)
# Copied: ILSVRC2012_val_00001137.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001137.xml (XML)
# Copied: ILSVRC2012_val_00001147.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001147.xml (XML)
# Copied: ILSVRC2012_val_00001187.JPEG (n02274259)
# Copied: ILSVRC2012_val_00001187.xml (XML)
# Copied: ILSVRC2012_val_00001191.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001191.xml (XML)
# Copied: ILSVRC2012_val_00001195.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001195.xml (XML)
# Copied: ILSVRC2012_val_00001206.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001206.xml (XML)
# Copied: ILSVRC2012_val_00001223.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001223.xml (XML)
# Copied: ILSVRC2012_val_00001225.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001225.xml (XML)
# Copied: ILSVRC2012_val_00001251.JPEG (n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834)
# Copied: ILSVRC2012_val_00001251.xml (XML)
# Copied: ILSVRC2012_val_00001284.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001284.xml (XML)
# Copied: ILSVRC2012_val_00001286.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00001286.xml (XML)
# Copied: ILSVRC2012_val_00001290.JPEG (n02274259)
# Copied: ILSVRC2012_val_00001290.xml (XML)
# Copied: ILSVRC2012_val_00001297.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001297.xml (XML)
# Copied: ILSVRC2012_val_00001302.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001302.xml (XML)
# Copied: ILSVRC2012_val_00001305.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001305.xml (XML)
# Copied: ILSVRC2012_val_00001313.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001313.xml (XML)
# Copied: ILSVRC2012_val_00001314.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001314.xml (XML)
# Copied: ILSVRC2012_val_00001341.JPEG (n03642806)
# Copied: ILSVRC2012_val_00001341.xml (XML)
# Copied: ILSVRC2012_val_00001354.JPEG (n04557648, n04557648)
# Copied: ILSVRC2012_val_00001354.xml (XML)
# Copied: ILSVRC2012_val_00001363.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001363.xml (XML)
# Copied: ILSVRC2012_val_00001371.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001371.xml (XML)
# Copied: ILSVRC2012_val_00001385.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001385.xml (XML)
# Copied: ILSVRC2012_val_00001392.JPEG (n03958227, n03958227, n03958227)
# Copied: ILSVRC2012_val_00001392.xml (XML)
# Copied: ILSVRC2012_val_00001397.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001397.xml (XML)
# Copied: ILSVRC2012_val_00001414.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00001414.xml (XML)
# Copied: ILSVRC2012_val_00001425.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001425.xml (XML)
# Copied: ILSVRC2012_val_00001445.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001445.xml (XML)
# Copied: ILSVRC2012_val_00001448.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001448.xml (XML)
# Copied: ILSVRC2012_val_00001526.JPEG (n03642806)
# Copied: ILSVRC2012_val_00001526.xml (XML)
# Copied: ILSVRC2012_val_00001536.JPEG (n02274259)
# Copied: ILSVRC2012_val_00001536.xml (XML)
# Copied: ILSVRC2012_val_00001538.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00001538.xml (XML)
# Copied: ILSVRC2012_val_00001548.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001548.xml (XML)
# Copied: ILSVRC2012_val_00001550.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001550.xml (XML)
# Copied: ILSVRC2012_val_00001555.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001555.xml (XML)
# Copied: ILSVRC2012_val_00001564.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001564.xml (XML)
# Copied: ILSVRC2012_val_00001571.JPEG (n03642806)
# Copied: ILSVRC2012_val_00001571.xml (XML)
# Copied: ILSVRC2012_val_00001577.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001577.xml (XML)
# Copied: ILSVRC2012_val_00001597.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001597.xml (XML)
# Copied: ILSVRC2012_val_00001624.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001624.xml (XML)
# Copied: ILSVRC2012_val_00001626.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00001626.xml (XML)
# Copied: ILSVRC2012_val_00001646.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00001646.xml (XML)
# Copied: ILSVRC2012_val_00001651.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001651.xml (XML)
# Copied: ILSVRC2012_val_00001668.JPEG (n04557648)
# Copied: ILSVRC2012_val_00001668.xml (XML)
# Copied: ILSVRC2012_val_00001686.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001686.xml (XML)
# Copied: ILSVRC2012_val_00001687.JPEG (n03642806)
# Copied: ILSVRC2012_val_00001687.xml (XML)
# Copied: ILSVRC2012_val_00001693.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001693.xml (XML)
# Copied: ILSVRC2012_val_00001696.JPEG (n02084071, n02084071, n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00001696.xml (XML)
# Copied: ILSVRC2012_val_00001702.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001702.xml (XML)
# Copied: ILSVRC2012_val_00001711.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001711.xml (XML)
# Copied: ILSVRC2012_val_00001717.JPEG (n02274259)
# Copied: ILSVRC2012_val_00001717.xml (XML)
# Copied: ILSVRC2012_val_00001758.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001758.xml (XML)
# Copied: ILSVRC2012_val_00001760.JPEG (n02206856)
# Copied: ILSVRC2012_val_00001760.xml (XML)
# Copied: ILSVRC2012_val_00001764.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00001764.xml (XML)
# Copied: ILSVRC2012_val_00001765.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001765.xml (XML)
# Copied: ILSVRC2012_val_00001768.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001768.xml (XML)
# Copied: ILSVRC2012_val_00001775.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001775.xml (XML)
# Copied: ILSVRC2012_val_00001779.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001779.xml (XML)
# Copied: ILSVRC2012_val_00001780.JPEG (n02815834, n02815834, n02815834)
# Copied: ILSVRC2012_val_00001780.xml (XML)
# Copied: ILSVRC2012_val_00001844.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001844.xml (XML)
# Copied: ILSVRC2012_val_00001849.JPEG (n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592)
# Copied: ILSVRC2012_val_00001849.xml (XML)
# Copied: ILSVRC2012_val_00001852.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001852.xml (XML)
# Copied: ILSVRC2012_val_00001858.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001858.xml (XML)
# Copied: ILSVRC2012_val_00001862.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001862.xml (XML)
# Copied: ILSVRC2012_val_00001900.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001900.xml (XML)
# Copied: ILSVRC2012_val_00001912.JPEG (n02815834, n02815834)
# Copied: ILSVRC2012_val_00001912.xml (XML)
# Copied: ILSVRC2012_val_00001923.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00001923.xml (XML)
# Copied: ILSVRC2012_val_00001927.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001927.xml (XML)
# Copied: ILSVRC2012_val_00001929.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001929.xml (XML)
# Copied: ILSVRC2012_val_00001937.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001937.xml (XML)
# Copied: ILSVRC2012_val_00001944.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00001944.xml (XML)
# Copied: ILSVRC2012_val_00001957.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001957.xml (XML)
# Copied: ILSVRC2012_val_00001968.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001968.xml (XML)
# Copied: ILSVRC2012_val_00001997.JPEG (n02084071)
# Copied: ILSVRC2012_val_00001997.xml (XML)
# Copied: ILSVRC2012_val_00002004.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002004.xml (XML)
# Copied: ILSVRC2012_val_00002012.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002012.xml (XML)
# Copied: ILSVRC2012_val_00002024.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002024.xml (XML)
# Copied: ILSVRC2012_val_00002035.JPEG (n02815834)
# Copied: ILSVRC2012_val_00002035.xml (XML)
# Copied: ILSVRC2012_val_00002059.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002059.xml (XML)
# Copied: ILSVRC2012_val_00002079.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002079.xml (XML)
# Copied: ILSVRC2012_val_00002097.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002097.xml (XML)
# Copied: ILSVRC2012_val_00002111.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002111.xml (XML)
# Copied: ILSVRC2012_val_00002150.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002150.xml (XML)
# Copied: ILSVRC2012_val_00002175.JPEG (n03642806, n03642806, n03642806, n03642806)
# Copied: ILSVRC2012_val_00002175.xml (XML)
# Copied: ILSVRC2012_val_00002187.JPEG (n07753592, n07753592)
# Copied: ILSVRC2012_val_00002187.xml (XML)
# Copied: ILSVRC2012_val_00002194.JPEG (n02084071, n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00002194.xml (XML)
# Copied: ILSVRC2012_val_00002208.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002208.xml (XML)
# Copied: ILSVRC2012_val_00002214.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002214.xml (XML)
# Copied: ILSVRC2012_val_00002222.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002222.xml (XML)
# Copied: ILSVRC2012_val_00002246.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002246.xml (XML)
# Copied: ILSVRC2012_val_00002277.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002277.xml (XML)
# Copied: ILSVRC2012_val_00002294.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002294.xml (XML)
# Copied: ILSVRC2012_val_00002296.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002296.xml (XML)
# Copied: ILSVRC2012_val_00002303.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002303.xml (XML)
# Copied: ILSVRC2012_val_00002315.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002315.xml (XML)
# Copied: ILSVRC2012_val_00002318.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002318.xml (XML)
# Copied: ILSVRC2012_val_00002328.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002328.xml (XML)
# Copied: ILSVRC2012_val_00002397.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002397.xml (XML)
# Copied: ILSVRC2012_val_00002398.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002398.xml (XML)
# Copied: ILSVRC2012_val_00002402.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002402.xml (XML)
# Copied: ILSVRC2012_val_00002406.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002406.xml (XML)
# Copied: ILSVRC2012_val_00002411.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002411.xml (XML)
# Copied: ILSVRC2012_val_00002416.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002416.xml (XML)
# Copied: ILSVRC2012_val_00002461.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002461.xml (XML)
# Copied: ILSVRC2012_val_00002481.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002481.xml (XML)
# Copied: ILSVRC2012_val_00002484.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002484.xml (XML)
# Copied: ILSVRC2012_val_00002549.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002549.xml (XML)
# Copied: ILSVRC2012_val_00002566.JPEG (n02206856)
# Copied: ILSVRC2012_val_00002566.xml (XML)
# Copied: ILSVRC2012_val_00002573.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002573.xml (XML)
# Copied: ILSVRC2012_val_00002576.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002576.xml (XML)
# Copied: ILSVRC2012_val_00002609.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002609.xml (XML)
# Copied: ILSVRC2012_val_00002635.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002635.xml (XML)
# Copied: ILSVRC2012_val_00002648.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002648.xml (XML)
# Copied: ILSVRC2012_val_00002650.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002650.xml (XML)
# Copied: ILSVRC2012_val_00002656.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002656.xml (XML)
# Copied: ILSVRC2012_val_00002672.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002672.xml (XML)
# Copied: ILSVRC2012_val_00002683.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002683.xml (XML)
# Copied: ILSVRC2012_val_00002687.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002687.xml (XML)
# Copied: ILSVRC2012_val_00002749.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002749.xml (XML)
# Copied: ILSVRC2012_val_00002765.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002765.xml (XML)
# Copied: ILSVRC2012_val_00002769.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002769.xml (XML)
# Copied: ILSVRC2012_val_00002773.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002773.xml (XML)
# Copied: ILSVRC2012_val_00002784.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002784.xml (XML)
# Copied: ILSVRC2012_val_00002787.JPEG (n02274259, n02274259)
# Copied: ILSVRC2012_val_00002787.xml (XML)
# Copied: ILSVRC2012_val_00002794.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002794.xml (XML)
# Copied: ILSVRC2012_val_00002824.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002824.xml (XML)
# Copied: ILSVRC2012_val_00002869.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002869.xml (XML)
# Copied: ILSVRC2012_val_00002885.JPEG (n03958227)
# Copied: ILSVRC2012_val_00002885.xml (XML)
# Copied: ILSVRC2012_val_00002906.JPEG (n02274259)
# Copied: ILSVRC2012_val_00002906.xml (XML)
# Copied: ILSVRC2012_val_00002921.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002921.xml (XML)
# Copied: ILSVRC2012_val_00002933.JPEG (n02084071)
# Copied: ILSVRC2012_val_00002933.xml (XML)
# Copied: ILSVRC2012_val_00002935.JPEG (n02274259, n02274259)
# Copied: ILSVRC2012_val_00002935.xml (XML)
# Copied: ILSVRC2012_val_00002940.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002940.xml (XML)
# Copied: ILSVRC2012_val_00002988.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00002988.xml (XML)
# Copied: ILSVRC2012_val_00003002.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003002.xml (XML)
# Copied: ILSVRC2012_val_00003026.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003026.xml (XML)
# Copied: ILSVRC2012_val_00003030.JPEG (n02206856)
# Copied: ILSVRC2012_val_00003030.xml (XML)
# Copied: ILSVRC2012_val_00003061.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003061.xml (XML)
# Copied: ILSVRC2012_val_00003069.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003069.xml (XML)
# Copied: ILSVRC2012_val_00003139.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003139.xml (XML)
# Copied: ILSVRC2012_val_00003142.JPEG (n03642806)
# Copied: ILSVRC2012_val_00003142.xml (XML)
# Copied: ILSVRC2012_val_00003154.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003154.xml (XML)
# Copied: ILSVRC2012_val_00003176.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003176.xml (XML)
# Copied: ILSVRC2012_val_00003179.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003179.xml (XML)
# Copied: ILSVRC2012_val_00003198.JPEG (n02084071, n02084071, n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00003198.xml (XML)
# Copied: ILSVRC2012_val_00003220.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003220.xml (XML)
# Copied: ILSVRC2012_val_00003232.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003232.xml (XML)
# Copied: ILSVRC2012_val_00003243.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003243.xml (XML)
# Copied: ILSVRC2012_val_00003267.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003267.xml (XML)
# Copied: ILSVRC2012_val_00003269.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003269.xml (XML)
# Copied: ILSVRC2012_val_00003318.JPEG (n04557648)
# Copied: ILSVRC2012_val_00003318.xml (XML)
# Copied: ILSVRC2012_val_00003340.JPEG (n04557648)
# Copied: ILSVRC2012_val_00003340.xml (XML)
# Copied: ILSVRC2012_val_00003355.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003355.xml (XML)
# Copied: ILSVRC2012_val_00003377.JPEG (n02084071, n04557648)
# Copied: ILSVRC2012_val_00003377.xml (XML)
# Copied: ILSVRC2012_val_00003407.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003407.xml (XML)
# Copied: ILSVRC2012_val_00003429.JPEG (n04557648)
# Copied: ILSVRC2012_val_00003429.xml (XML)
# Copied: ILSVRC2012_val_00003481.JPEG (n02274259)
# Copied: ILSVRC2012_val_00003481.xml (XML)
# Copied: ILSVRC2012_val_00003485.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003485.xml (XML)
# Copied: ILSVRC2012_val_00003490.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003490.xml (XML)
# Copied: ILSVRC2012_val_00003498.JPEG (n02274259)
# Copied: ILSVRC2012_val_00003498.xml (XML)
# Copied: ILSVRC2012_val_00003522.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003522.xml (XML)
# Copied: ILSVRC2012_val_00003549.JPEG (n04557648)
# Copied: ILSVRC2012_val_00003549.xml (XML)
# Copied: ILSVRC2012_val_00003597.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003597.xml (XML)
# Copied: ILSVRC2012_val_00003615.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003615.xml (XML)
# Copied: ILSVRC2012_val_00003623.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003623.xml (XML)
# Copied: ILSVRC2012_val_00003628.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00003628.xml (XML)
# Copied: ILSVRC2012_val_00003638.JPEG (n02084071, n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00003638.xml (XML)
# Copied: ILSVRC2012_val_00003683.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003683.xml (XML)
# Copied: ILSVRC2012_val_00003698.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003698.xml (XML)
# Copied: ILSVRC2012_val_00003711.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003711.xml (XML)
# Copied: ILSVRC2012_val_00003714.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003714.xml (XML)
# Copied: ILSVRC2012_val_00003723.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003723.xml (XML)
# Copied: ILSVRC2012_val_00003729.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003729.xml (XML)
# Copied: ILSVRC2012_val_00003754.JPEG (n04557648)
# Copied: ILSVRC2012_val_00003754.xml (XML)
# Copied: ILSVRC2012_val_00003769.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003769.xml (XML)
# Copied: ILSVRC2012_val_00003774.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003774.xml (XML)
# Copied: ILSVRC2012_val_00003789.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003789.xml (XML)
# Copied: ILSVRC2012_val_00003791.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003791.xml (XML)
# Copied: ILSVRC2012_val_00003792.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003792.xml (XML)
# Copied: ILSVRC2012_val_00003794.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003794.xml (XML)
# Copied: ILSVRC2012_val_00003810.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003810.xml (XML)
# Copied: ILSVRC2012_val_00003832.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003832.xml (XML)
# Copied: ILSVRC2012_val_00003834.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003834.xml (XML)
# Copied: ILSVRC2012_val_00003837.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003837.xml (XML)
# Copied: ILSVRC2012_val_00003851.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003851.xml (XML)
# Copied: ILSVRC2012_val_00003856.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003856.xml (XML)
# Copied: ILSVRC2012_val_00003864.JPEG (n03337140)
# Copied: ILSVRC2012_val_00003864.xml (XML)
# Copied: ILSVRC2012_val_00003898.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003898.xml (XML)
# Copied: ILSVRC2012_val_00003908.JPEG (n07697537)
# Copied: ILSVRC2012_val_00003908.xml (XML)
# Copied: ILSVRC2012_val_00003910.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003910.xml (XML)
# Copied: ILSVRC2012_val_00003929.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003929.xml (XML)
# Copied: ILSVRC2012_val_00003938.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003938.xml (XML)
# Copied: ILSVRC2012_val_00003953.JPEG (n02084071)
# Copied: ILSVRC2012_val_00003953.xml (XML)
# Copied: ILSVRC2012_val_00003968.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00003968.xml (XML)
# Copied: ILSVRC2012_val_00004008.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004008.xml (XML)
# Copied: ILSVRC2012_val_00004011.JPEG (n02274259, n02274259)
# Copied: ILSVRC2012_val_00004011.xml (XML)
# Copied: ILSVRC2012_val_00004061.JPEG (n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834, n02815834)
# Copied: ILSVRC2012_val_00004061.xml (XML)
# Copied: ILSVRC2012_val_00004073.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004073.xml (XML)
# Copied: ILSVRC2012_val_00004074.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004074.xml (XML)
# Copied: ILSVRC2012_val_00004085.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004085.xml (XML)
# Copied: ILSVRC2012_val_00004129.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004129.xml (XML)
# Copied: ILSVRC2012_val_00004134.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004134.xml (XML)
# Copied: ILSVRC2012_val_00004141.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004141.xml (XML)
# Copied: ILSVRC2012_val_00004185.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004185.xml (XML)
# Copied: ILSVRC2012_val_00004192.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004192.xml (XML)
# Copied: ILSVRC2012_val_00004198.JPEG (n07753592, n07753592, n07753592)
# Copied: ILSVRC2012_val_00004198.xml (XML)
# Copied: ILSVRC2012_val_00004208.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00004208.xml (XML)
# Copied: ILSVRC2012_val_00004225.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004225.xml (XML)
# Copied: ILSVRC2012_val_00004228.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004228.xml (XML)
# Copied: ILSVRC2012_val_00004261.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004261.xml (XML)
# Copied: ILSVRC2012_val_00004274.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004274.xml (XML)
# Copied: ILSVRC2012_val_00004278.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004278.xml (XML)
# Copied: ILSVRC2012_val_00004288.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00004288.xml (XML)
# Copied: ILSVRC2012_val_00004325.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004325.xml (XML)
# Copied: ILSVRC2012_val_00004341.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004341.xml (XML)
# Copied: ILSVRC2012_val_00004354.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004354.xml (XML)
# Copied: ILSVRC2012_val_00004366.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004366.xml (XML)
# Copied: ILSVRC2012_val_00004378.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004378.xml (XML)
# Copied: ILSVRC2012_val_00004397.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004397.xml (XML)
# Copied: ILSVRC2012_val_00004403.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004403.xml (XML)
# Copied: ILSVRC2012_val_00004407.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004407.xml (XML)
# Copied: ILSVRC2012_val_00004410.JPEG (n03337140)
# Copied: ILSVRC2012_val_00004410.xml (XML)
# Copied: ILSVRC2012_val_00004434.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004434.xml (XML)
# Copied: ILSVRC2012_val_00004435.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004435.xml (XML)
# Copied: ILSVRC2012_val_00004436.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004436.xml (XML)
# Copied: ILSVRC2012_val_00004453.JPEG (n02274259)
# Copied: ILSVRC2012_val_00004453.xml (XML)
# Copied: ILSVRC2012_val_00004474.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004474.xml (XML)
# Copied: ILSVRC2012_val_00004477.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004477.xml (XML)
# Copied: ILSVRC2012_val_00004506.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004506.xml (XML)
# Copied: ILSVRC2012_val_00004511.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004511.xml (XML)
# Copied: ILSVRC2012_val_00004522.JPEG (n02815834, n02815834)
# Copied: ILSVRC2012_val_00004522.xml (XML)
# Copied: ILSVRC2012_val_00004539.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004539.xml (XML)
# Copied: ILSVRC2012_val_00004542.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004542.xml (XML)
# Copied: ILSVRC2012_val_00004548.JPEG (n02084071, n02084071, n02084071, n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00004548.xml (XML)
# Copied: ILSVRC2012_val_00004549.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004549.xml (XML)
# Copied: ILSVRC2012_val_00004563.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004563.xml (XML)
# Copied: ILSVRC2012_val_00004569.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004569.xml (XML)
# Copied: ILSVRC2012_val_00004590.JPEG (n02274259)
# Copied: ILSVRC2012_val_00004590.xml (XML)
# Copied: ILSVRC2012_val_00004611.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004611.xml (XML)
# Copied: ILSVRC2012_val_00004614.JPEG (n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592)
# Copied: ILSVRC2012_val_00004614.xml (XML)
# Copied: ILSVRC2012_val_00004631.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004631.xml (XML)
# Copied: ILSVRC2012_val_00004634.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004634.xml (XML)
# Copied: ILSVRC2012_val_00004642.JPEG (n03642806)
# Copied: ILSVRC2012_val_00004642.xml (XML)
# Copied: ILSVRC2012_val_00004657.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004657.xml (XML)
# Copied: ILSVRC2012_val_00004666.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004666.xml (XML)
# Copied: ILSVRC2012_val_00004671.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004671.xml (XML)
# Copied: ILSVRC2012_val_00004674.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004674.xml (XML)
# Copied: ILSVRC2012_val_00004684.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004684.xml (XML)
# Copied: ILSVRC2012_val_00004687.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004687.xml (XML)
# Copied: ILSVRC2012_val_00004711.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004711.xml (XML)
# Copied: ILSVRC2012_val_00004713.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004713.xml (XML)
# Copied: ILSVRC2012_val_00004731.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004731.xml (XML)
# Copied: ILSVRC2012_val_00004748.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004748.xml (XML)
# Copied: ILSVRC2012_val_00004750.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004750.xml (XML)
# Copied: ILSVRC2012_val_00004776.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004776.xml (XML)
# Copied: ILSVRC2012_val_00004777.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004777.xml (XML)
# Copied: ILSVRC2012_val_00004804.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004804.xml (XML)
# Copied: ILSVRC2012_val_00004823.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004823.xml (XML)
# Copied: ILSVRC2012_val_00004850.JPEG (n02274259)
# Copied: ILSVRC2012_val_00004850.xml (XML)
# Copied: ILSVRC2012_val_00004883.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004883.xml (XML)
# Copied: ILSVRC2012_val_00004956.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004956.xml (XML)
# Copied: ILSVRC2012_val_00004967.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004967.xml (XML)
# Copied: ILSVRC2012_val_00004972.JPEG (n02815834, n02815834)
# Copied: ILSVRC2012_val_00004972.xml (XML)
# Copied: ILSVRC2012_val_00004974.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004974.xml (XML)
# Copied: ILSVRC2012_val_00004977.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004977.xml (XML)
# Copied: ILSVRC2012_val_00004989.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004989.xml (XML)
# Copied: ILSVRC2012_val_00004992.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004992.xml (XML)
# Copied: ILSVRC2012_val_00004995.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00004995.xml (XML)
# Copied: ILSVRC2012_val_00004996.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004996.xml (XML)
# Copied: ILSVRC2012_val_00004997.JPEG (n02084071)
# Copied: ILSVRC2012_val_00004997.xml (XML)
# Copied: ILSVRC2012_val_00005000.JPEG (n02274259)
# Copied: ILSVRC2012_val_00005000.xml (XML)
# Copied: ILSVRC2012_val_00005017.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005017.xml (XML)
# Copied: ILSVRC2012_val_00005021.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00005021.xml (XML)
# Copied: ILSVRC2012_val_00005043.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005043.xml (XML)
# Copied: ILSVRC2012_val_00005059.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005059.xml (XML)
# Copied: ILSVRC2012_val_00005060.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00005060.xml (XML)
# Copied: ILSVRC2012_val_00005064.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005064.xml (XML)
# Copied: ILSVRC2012_val_00005082.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005082.xml (XML)
# Copied: ILSVRC2012_val_00005117.JPEG (n02274259, n02274259, n02274259, n02274259, n02274259, n02274259)
# Copied: ILSVRC2012_val_00005117.xml (XML)
# Copied: ILSVRC2012_val_00005137.JPEG (n02274259)
# Copied: ILSVRC2012_val_00005137.xml (XML)
# Copied: ILSVRC2012_val_00005139.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005139.xml (XML)
# Copied: ILSVRC2012_val_00005146.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005146.xml (XML)
# Copied: ILSVRC2012_val_00005157.JPEG (n02274259)
# Copied: ILSVRC2012_val_00005157.xml (XML)
# Copied: ILSVRC2012_val_00005175.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00005175.xml (XML)
# Copied: ILSVRC2012_val_00005206.JPEG (n02084071, n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00005206.xml (XML)
# Copied: ILSVRC2012_val_00005217.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005217.xml (XML)
# Copied: ILSVRC2012_val_00005238.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005238.xml (XML)
# Copied: ILSVRC2012_val_00005255.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00005255.xml (XML)
# Copied: ILSVRC2012_val_00005258.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005258.xml (XML)
# Copied: ILSVRC2012_val_00005267.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00005267.xml (XML)
# Copied: ILSVRC2012_val_00005275.JPEG (n03642806, n03642806)
# Copied: ILSVRC2012_val_00005275.xml (XML)
# Copied: ILSVRC2012_val_00005279.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005279.xml (XML)
# Copied: ILSVRC2012_val_00005291.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005291.xml (XML)
# Copied: ILSVRC2012_val_00005317.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005317.xml (XML)
# Copied: ILSVRC2012_val_00005334.JPEG (n02815834)
# Copied: ILSVRC2012_val_00005334.xml (XML)
# Copied: ILSVRC2012_val_00005340.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005340.xml (XML)
# Copied: ILSVRC2012_val_00005364.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00005364.xml (XML)
# Copied: ILSVRC2012_val_00005395.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005395.xml (XML)
# Copied: ILSVRC2012_val_00005397.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005397.xml (XML)
# Copied: ILSVRC2012_val_00005404.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005404.xml (XML)
# Copied: ILSVRC2012_val_00005406.JPEG (n03958227, n03958227)
# Copied: ILSVRC2012_val_00005406.xml (XML)
# Copied: ILSVRC2012_val_00005453.JPEG (n03337140)
# Copied: ILSVRC2012_val_00005453.xml (XML)
# Copied: ILSVRC2012_val_00005471.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005471.xml (XML)
# Copied: ILSVRC2012_val_00005481.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005481.xml (XML)
# Copied: ILSVRC2012_val_00005493.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00005493.xml (XML)
# Copied: ILSVRC2012_val_00005495.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00005495.xml (XML)
# Copied: ILSVRC2012_val_00005507.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005507.xml (XML)
# Copied: ILSVRC2012_val_00005508.JPEG (n02815834)
# Copied: ILSVRC2012_val_00005508.xml (XML)
# Copied: ILSVRC2012_val_00005524.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00005524.xml (XML)
# Copied: ILSVRC2012_val_00005559.JPEG (n02206856)
# Copied: ILSVRC2012_val_00005559.xml (XML)
# Copied: ILSVRC2012_val_00005564.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00005564.xml (XML)
# Copied: ILSVRC2012_val_00005575.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005575.xml (XML)
# Copied: ILSVRC2012_val_00005583.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005583.xml (XML)
# Copied: ILSVRC2012_val_00005587.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005587.xml (XML)
# Copied: ILSVRC2012_val_00005618.JPEG (n03337140, n03337140)
# Copied: ILSVRC2012_val_00005618.xml (XML)
# Copied: ILSVRC2012_val_00005639.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005639.xml (XML)
# Copied: ILSVRC2012_val_00005658.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005658.xml (XML)
# Copied: ILSVRC2012_val_00005662.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005662.xml (XML)
# Copied: ILSVRC2012_val_00005667.JPEG (n03337140)
# Copied: ILSVRC2012_val_00005667.xml (XML)
# Copied: ILSVRC2012_val_00005677.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005677.xml (XML)
# Copied: ILSVRC2012_val_00005685.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005685.xml (XML)
# Copied: ILSVRC2012_val_00005687.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005687.xml (XML)
# Copied: ILSVRC2012_val_00005699.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005699.xml (XML)
# Copied: ILSVRC2012_val_00005710.JPEG (n07697537, n07697537, n07697537)
# Copied: ILSVRC2012_val_00005710.xml (XML)
# Copied: ILSVRC2012_val_00005718.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00005718.xml (XML)
# Copied: ILSVRC2012_val_00005746.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005746.xml (XML)
# Copied: ILSVRC2012_val_00005750.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005750.xml (XML)
# Copied: ILSVRC2012_val_00005758.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00005758.xml (XML)
# Copied: ILSVRC2012_val_00005767.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005767.xml (XML)
# Copied: ILSVRC2012_val_00005786.JPEG (n02274259)
# Copied: ILSVRC2012_val_00005786.xml (XML)
# Copied: ILSVRC2012_val_00005816.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005816.xml (XML)
# Copied: ILSVRC2012_val_00005820.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005820.xml (XML)
# Copied: ILSVRC2012_val_00005831.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005831.xml (XML)
# Copied: ILSVRC2012_val_00005867.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005867.xml (XML)
# Copied: ILSVRC2012_val_00005886.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00005886.xml (XML)
# Copied: ILSVRC2012_val_00005900.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005900.xml (XML)
# Copied: ILSVRC2012_val_00005902.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005902.xml (XML)
# Copied: ILSVRC2012_val_00005904.JPEG (n02274259)
# Copied: ILSVRC2012_val_00005904.xml (XML)
# Copied: ILSVRC2012_val_00005905.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00005905.xml (XML)
# Copied: ILSVRC2012_val_00005909.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005909.xml (XML)
# Copied: ILSVRC2012_val_00005923.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005923.xml (XML)
# Copied: ILSVRC2012_val_00005942.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005942.xml (XML)
# Copied: ILSVRC2012_val_00005952.JPEG (n02274259)
# Copied: ILSVRC2012_val_00005952.xml (XML)
# Copied: ILSVRC2012_val_00005982.JPEG (n02084071)
# Copied: ILSVRC2012_val_00005982.xml (XML)
# Copied: ILSVRC2012_val_00006002.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006002.xml (XML)
# Copied: ILSVRC2012_val_00006035.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006035.xml (XML)
# Copied: ILSVRC2012_val_00006052.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006052.xml (XML)
# Copied: ILSVRC2012_val_00006063.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006063.xml (XML)
# Copied: ILSVRC2012_val_00006065.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006065.xml (XML)
# Copied: ILSVRC2012_val_00006069.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006069.xml (XML)
# Copied: ILSVRC2012_val_00006078.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006078.xml (XML)
# Copied: ILSVRC2012_val_00006079.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006079.xml (XML)
# Copied: ILSVRC2012_val_00006083.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006083.xml (XML)
# Copied: ILSVRC2012_val_00006114.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006114.xml (XML)
# Copied: ILSVRC2012_val_00006265.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006265.xml (XML)
# Copied: ILSVRC2012_val_00006273.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006273.xml (XML)
# Copied: ILSVRC2012_val_00006297.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006297.xml (XML)
# Copied: ILSVRC2012_val_00006382.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006382.xml (XML)
# Copied: ILSVRC2012_val_00006396.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006396.xml (XML)
# Copied: ILSVRC2012_val_00006404.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006404.xml (XML)
# Copied: ILSVRC2012_val_00006415.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006415.xml (XML)
# Copied: ILSVRC2012_val_00006416.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006416.xml (XML)
# Copied: ILSVRC2012_val_00006423.JPEG (n03642806)
# Copied: ILSVRC2012_val_00006423.xml (XML)
# Copied: ILSVRC2012_val_00006438.JPEG (n03642806)
# Copied: ILSVRC2012_val_00006438.xml (XML)
# Copied: ILSVRC2012_val_00006456.JPEG (n03337140)
# Copied: ILSVRC2012_val_00006456.xml (XML)
# Copied: ILSVRC2012_val_00006473.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006473.xml (XML)
# Copied: ILSVRC2012_val_00006484.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006484.xml (XML)
# Copied: ILSVRC2012_val_00006486.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006486.xml (XML)
# Copied: ILSVRC2012_val_00006495.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006495.xml (XML)
# Copied: ILSVRC2012_val_00006505.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006505.xml (XML)
# Copied: ILSVRC2012_val_00006514.JPEG (n02274259)
# Copied: ILSVRC2012_val_00006514.xml (XML)
# Copied: ILSVRC2012_val_00006531.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006531.xml (XML)
# Copied: ILSVRC2012_val_00006537.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006537.xml (XML)
# Copied: ILSVRC2012_val_00006544.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006544.xml (XML)
# Copied: ILSVRC2012_val_00006584.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006584.xml (XML)
# Copied: ILSVRC2012_val_00006585.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006585.xml (XML)
# Copied: ILSVRC2012_val_00006586.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006586.xml (XML)
# Copied: ILSVRC2012_val_00006615.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006615.xml (XML)
# Copied: ILSVRC2012_val_00006630.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006630.xml (XML)
# Copied: ILSVRC2012_val_00006646.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006646.xml (XML)
# Copied: ILSVRC2012_val_00006649.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006649.xml (XML)
# Copied: ILSVRC2012_val_00006659.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00006659.xml (XML)
# Copied: ILSVRC2012_val_00006664.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006664.xml (XML)
# Copied: ILSVRC2012_val_00006665.JPEG (n03642806)
# Copied: ILSVRC2012_val_00006665.xml (XML)
# Copied: ILSVRC2012_val_00006704.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006704.xml (XML)
# Copied: ILSVRC2012_val_00006728.JPEG (n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592)
# Copied: ILSVRC2012_val_00006728.xml (XML)
# Copied: ILSVRC2012_val_00006815.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006815.xml (XML)
# Copied: ILSVRC2012_val_00006819.JPEG (n02274259)
# Copied: ILSVRC2012_val_00006819.xml (XML)
# Copied: ILSVRC2012_val_00006824.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006824.xml (XML)
# Copied: ILSVRC2012_val_00006827.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006827.xml (XML)
# Copied: ILSVRC2012_val_00006837.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2012_val_00006837.xml (XML)
# Copied: ILSVRC2012_val_00006840.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006840.xml (XML)
# Copied: ILSVRC2012_val_00006848.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006848.xml (XML)
# Copied: ILSVRC2012_val_00006857.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006857.xml (XML)
# Copied: ILSVRC2012_val_00006866.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006866.xml (XML)
# Copied: ILSVRC2012_val_00006887.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006887.xml (XML)
# Copied: ILSVRC2012_val_00006892.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006892.xml (XML)
# Copied: ILSVRC2012_val_00006895.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006895.xml (XML)
# Copied: ILSVRC2012_val_00006900.JPEG (n02084071, n02084071)
# Copied: ILSVRC2012_val_00006900.xml (XML)
# Copied: ILSVRC2012_val_00006920.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006920.xml (XML)
# Copied: ILSVRC2012_val_00006935.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006935.xml (XML)
# Copied: ILSVRC2012_val_00006949.JPEG (n04557648)
# Copied: ILSVRC2012_val_00006949.xml (XML)
# Copied: ILSVRC2012_val_00006981.JPEG (n02084071)
# Copied: ILSVRC2012_val_00006981.xml (XML)
# Copied: ILSVRC2012_val_00007001.JPEG (n02084071)
# Copied: ILSVRC2012_val_00007001.xml (XML)
# Copied: ILSVRC2012_val_00007002.JPEG (n02084071)
# Copied: ILSVRC2012_val_00007002.xml (XML)
# Copied: ILSVRC2012_val_00007016.JPEG (n02274259)
# Copied: ILSVRC2012_val_00007016.xml (XML)
# Copied: ILSVRC2012_val_00007032.JPEG (n02084071)
# Copied: ILSVRC2012_val_00007032.xml (XML)
# Copied: ILSVRC2012_val_00007033.JPEG (n02084071)
# Copied: ILSVRC2012_val_00007033.xml (XML)
# Copied: ILSVRC2012_val_00007056.JPEG (n02084071)
# Copied: ILSVRC2012_val_00007056.xml (XML)
# Copied: ILSVRC2012_val_00007057.JPEG (n02084071)
# ...
# Copied: ILSVRC2013_val_00000411.JPEG (n03958227)
# Copied: ILSVRC2013_val_00000411.xml (XML)
# Copied: ILSVRC2013_val_00000434.JPEG (n03958227)
# Copied: ILSVRC2013_val_00000434.xml (XML)
# Copied: ILSVRC2013_val_00000448.JPEG (n03642806)
# Copied: ILSVRC2013_val_00000448.xml (XML)
# Copied: ILSVRC2013_val_00000463.JPEG (n04557648, n04557648, n04557648)
# Copied: ILSVRC2013_val_00000463.xml (XML)
# Copied: ILSVRC2013_val_00000464.JPEG (n02815834, n02815834)
# Copied: ILSVRC2013_val_00000464.xml (XML)
# Copied: ILSVRC2013_val_00000470.JPEG (n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00000470.xml (XML)
# Copied: ILSVRC2013_val_00000530.JPEG (n02206856)
# Copied: ILSVRC2013_val_00000530.xml (XML)
# Copied: ILSVRC2013_val_00000531.JPEG (n02084071)
# Copied: ILSVRC2013_val_00000531.xml (XML)
# Copied: ILSVRC2013_val_00000660.JPEG (n03958227, n03958227)
# Copied: ILSVRC2013_val_00000660.xml (XML)
# Copied: ILSVRC2013_val_00000822.JPEG (n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00000822.xml (XML)
# Copied: ILSVRC2013_val_00000833.JPEG (n03958227, n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00000833.xml (XML)
# Copied: ILSVRC2013_val_00000971.JPEG (n04557648, n04557648, n04557648)
# Copied: ILSVRC2013_val_00000971.xml (XML)
# Copied: ILSVRC2013_val_00001022.JPEG (n03958227, n03958227, n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00001022.xml (XML)
# Copied: ILSVRC2013_val_00001044.JPEG (n04557648, n04557648, n04557648, n04557648, n04557648)
# Copied: ILSVRC2013_val_00001044.xml (XML)
# Copied: ILSVRC2013_val_00001095.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001095.xml (XML)
# Copied: ILSVRC2013_val_00001157.JPEG (n07753592, n07753592, n07753592, n07753592, n07753592)
# Copied: ILSVRC2013_val_00001157.xml (XML)
# Copied: ILSVRC2013_val_00001183.JPEG (n03642806)
# Copied: ILSVRC2013_val_00001183.xml (XML)
# Copied: ILSVRC2013_val_00001220.JPEG (n03337140)
# Copied: ILSVRC2013_val_00001220.xml (XML)
# Copied: ILSVRC2013_val_00001246.JPEG (n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592)
# Copied: ILSVRC2013_val_00001246.xml (XML)
# Copied: ILSVRC2013_val_00001270.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001270.xml (XML)
# Copied: ILSVRC2013_val_00001277.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001277.xml (XML)
# Copied: ILSVRC2013_val_00001299.JPEG (n03337140)
# Copied: ILSVRC2013_val_00001299.xml (XML)
# Copied: ILSVRC2013_val_00001304.JPEG (n04557648)
# Copied: ILSVRC2013_val_00001304.xml (XML)
# Copied: ILSVRC2013_val_00001311.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001311.xml (XML)
# Copied: ILSVRC2013_val_00001344.JPEG (n03337140)
# Copied: ILSVRC2013_val_00001344.xml (XML)
# Copied: ILSVRC2013_val_00001360.JPEG (n03958227, n03958227, n03958227, n04557648)
# Copied: ILSVRC2013_val_00001360.xml (XML)
# Copied: ILSVRC2013_val_00001402.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001402.xml (XML)
# Copied: ILSVRC2013_val_00001451.JPEG (n04557648, n04557648)
# Copied: ILSVRC2013_val_00001451.xml (XML)
# Copied: ILSVRC2013_val_00001467.JPEG (n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00001467.xml (XML)
# Copied: ILSVRC2013_val_00001494.JPEG (n03958227, n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00001494.xml (XML)
# Copied: ILSVRC2013_val_00001507.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001507.xml (XML)
# Copied: ILSVRC2013_val_00001534.JPEG (n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00001534.xml (XML)
# Copied: ILSVRC2013_val_00001594.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001594.xml (XML)
# Copied: ILSVRC2013_val_00001624.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001624.xml (XML)
# Copied: ILSVRC2013_val_00001632.JPEG (n03958227, n03958227)
# Copied: ILSVRC2013_val_00001632.xml (XML)
# Copied: ILSVRC2013_val_00001641.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001641.xml (XML)
# Copied: ILSVRC2013_val_00001681.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001681.xml (XML)
# Copied: ILSVRC2013_val_00001685.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001685.xml (XML)
# Copied: ILSVRC2013_val_00001705.JPEG (n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00001705.xml (XML)
# Copied: ILSVRC2013_val_00001776.JPEG (n03958227)
# Copied: ILSVRC2013_val_00001776.xml (XML)
# Copied: ILSVRC2013_val_00001941.JPEG (n04557648)
# Copied: ILSVRC2013_val_00001941.xml (XML)
# Copied: ILSVRC2013_val_00001970.JPEG (n03337140)
# Copied: ILSVRC2013_val_00001970.xml (XML)
# Copied: ILSVRC2013_val_00001996.JPEG (n03642806)
# Copied: ILSVRC2013_val_00001996.xml (XML)
# Copied: ILSVRC2013_val_00002057.JPEG (n02815834)
# Copied: ILSVRC2013_val_00002057.xml (XML)
# Copied: ILSVRC2013_val_00002089.JPEG (n03958227)
# Copied: ILSVRC2013_val_00002089.xml (XML)
# Copied: ILSVRC2013_val_00002117.JPEG (n04557648)
# Copied: ILSVRC2013_val_00002117.xml (XML)
# Copied: ILSVRC2013_val_00002157.JPEG (n03642806)
# Copied: ILSVRC2013_val_00002157.xml (XML)
# Copied: ILSVRC2013_val_00002195.JPEG (n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00002195.xml (XML)
# Copied: ILSVRC2013_val_00002263.JPEG (n03642806)
# Copied: ILSVRC2013_val_00002263.xml (XML)
# Copied: ILSVRC2013_val_00002336.JPEG (n04557648)
# Copied: ILSVRC2013_val_00002336.xml (XML)
# Copied: ILSVRC2013_val_00002366.JPEG (n02084071)
# Copied: ILSVRC2013_val_00002366.xml (XML)
# Copied: ILSVRC2013_val_00002409.JPEG (n03958227)
# Copied: ILSVRC2013_val_00002409.xml (XML)
# Copied: ILSVRC2013_val_00002446.JPEG (n03642806)
# Copied: ILSVRC2013_val_00002446.xml (XML)
# Copied: ILSVRC2013_val_00002467.JPEG (n02084071)
# Copied: ILSVRC2013_val_00002467.xml (XML)
# Copied: ILSVRC2013_val_00002481.JPEG (n04557648)
# Copied: ILSVRC2013_val_00002481.xml (XML)
# Copied: ILSVRC2013_val_00002494.JPEG (n03958227)
# Copied: ILSVRC2013_val_00002494.xml (XML)
# Copied: ILSVRC2013_val_00002515.JPEG (n02084071)
# Copied: ILSVRC2013_val_00002515.xml (XML)
# Copied: ILSVRC2013_val_00002519.JPEG (n02206856)
# Copied: ILSVRC2013_val_00002519.xml (XML)
# Copied: ILSVRC2013_val_00002538.JPEG (n03337140, n03337140)
# Copied: ILSVRC2013_val_00002538.xml (XML)
# Copied: ILSVRC2013_val_00002545.JPEG (n02084071)
# Copied: ILSVRC2013_val_00002545.xml (XML)
# Copied: ILSVRC2013_val_00002551.JPEG (n04557648, n04557648)
# Copied: ILSVRC2013_val_00002551.xml (XML)
# Copied: ILSVRC2013_val_00002556.JPEG (n03642806)
# Copied: ILSVRC2013_val_00002556.xml (XML)
# Copied: ILSVRC2013_val_00002557.JPEG (n07697537)
# Copied: ILSVRC2013_val_00002557.xml (XML)
# Copied: ILSVRC2013_val_00002660.JPEG (n02084071, n02084071)
# Copied: ILSVRC2013_val_00002660.xml (XML)
# Copied: ILSVRC2013_val_00002669.JPEG (n02815834, n03642806)
# Copied: ILSVRC2013_val_00002669.xml (XML)
# Copied: ILSVRC2013_val_00002697.JPEG (n07697537)
# Copied: ILSVRC2013_val_00002697.xml (XML)
# Copied: ILSVRC2013_val_00002710.JPEG (n02084071)
# Copied: ILSVRC2013_val_00002710.xml (XML)
# Copied: ILSVRC2013_val_00002726.JPEG (n02084071, n02084071)
# Copied: ILSVRC2013_val_00002726.xml (XML)
# Copied: ILSVRC2013_val_00002738.JPEG (n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00002738.xml (XML)
# Copied: ILSVRC2013_val_00002754.JPEG (n07697537)
# Copied: ILSVRC2013_val_00002754.xml (XML)
# Copied: ILSVRC2013_val_00002767.JPEG (n03642806)
# Copied: ILSVRC2013_val_00002767.xml (XML)
# Copied: ILSVRC2013_val_00002768.JPEG (n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00002768.xml (XML)
# Copied: ILSVRC2013_val_00002798.JPEG (n03958227, n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00002798.xml (XML)
# Copied: ILSVRC2013_val_00002815.JPEG (n04557648)
# Copied: ILSVRC2013_val_00002815.xml (XML)
# Copied: ILSVRC2013_val_00002825.JPEG (n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00002825.xml (XML)
# Copied: ILSVRC2013_val_00002898.JPEG (n03642806)
# Copied: ILSVRC2013_val_00002898.xml (XML)
# Copied: ILSVRC2013_val_00002914.JPEG (n03642806)
# Copied: ILSVRC2013_val_00002914.xml (XML)
# Copied: ILSVRC2013_val_00002968.JPEG (n04557648)
# Copied: ILSVRC2013_val_00002968.xml (XML)
# Copied: ILSVRC2013_val_00002978.JPEG (n02084071)
# Copied: ILSVRC2013_val_00002978.xml (XML)
# Copied: ILSVRC2013_val_00002981.JPEG (n03642806)
# Copied: ILSVRC2013_val_00002981.xml (XML)
# Copied: ILSVRC2013_val_00002986.JPEG (n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00002986.xml (XML)
# Copied: ILSVRC2013_val_00003000.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003000.xml (XML)
# Copied: ILSVRC2013_val_00003005.JPEG (n03642806, n03642806)
# Copied: ILSVRC2013_val_00003005.xml (XML)
# Copied: ILSVRC2013_val_00003022.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003022.xml (XML)
# Copied: ILSVRC2013_val_00003044.JPEG (n07753592, n07753592, n07753592, n07753592, n07753592, n07753592, n07753592)
# Copied: ILSVRC2013_val_00003044.xml (XML)
# Copied: ILSVRC2013_val_00003051.JPEG (n02274259)
# Copied: ILSVRC2013_val_00003051.xml (XML)
# Copied: ILSVRC2013_val_00003064.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003064.xml (XML)
# Copied: ILSVRC2013_val_00003085.JPEG (n02084071, n02084071, n02084071)
# Copied: ILSVRC2013_val_00003085.xml (XML)
# Copied: ILSVRC2013_val_00003111.JPEG (n03337140)
# Copied: ILSVRC2013_val_00003111.xml (XML)
# Copied: ILSVRC2013_val_00003123.JPEG (n04557648)
# Copied: ILSVRC2013_val_00003123.xml (XML)
# Copied: ILSVRC2013_val_00003143.JPEG (n04557648)
# Copied: ILSVRC2013_val_00003143.xml (XML)
# Copied: ILSVRC2013_val_00003159.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003159.xml (XML)
# Copied: ILSVRC2013_val_00003195.JPEG (n03642806)
# Copied: ILSVRC2013_val_00003195.xml (XML)
# Copied: ILSVRC2013_val_00003197.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003197.xml (XML)
# Copied: ILSVRC2013_val_00003213.JPEG (n03642806)
# Copied: ILSVRC2013_val_00003213.xml (XML)
# Copied: ILSVRC2013_val_00003281.JPEG (n03642806)
# Copied: ILSVRC2013_val_00003281.xml (XML)
# Copied: ILSVRC2013_val_00003310.JPEG (n02084071, n02084071)
# Copied: ILSVRC2013_val_00003310.xml (XML)
# Copied: ILSVRC2013_val_00003311.JPEG (n03958227)
# Copied: ILSVRC2013_val_00003311.xml (XML)
# Copied: ILSVRC2013_val_00003320.JPEG (n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00003320.xml (XML)
# Copied: ILSVRC2013_val_00003356.JPEG (n03958227, n03958227)
# Copied: ILSVRC2013_val_00003356.xml (XML)
# Copied: ILSVRC2013_val_00003385.JPEG (n07697537)
# Copied: ILSVRC2013_val_00003385.xml (XML)
# Copied: ILSVRC2013_val_00003430.JPEG (n03642806)
# Copied: ILSVRC2013_val_00003430.xml (XML)
# Copied: ILSVRC2013_val_00003437.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003437.xml (XML)
# Copied: ILSVRC2013_val_00003446.JPEG (n02274259)
# Copied: ILSVRC2013_val_00003446.xml (XML)
# Copied: ILSVRC2013_val_00003461.JPEG (n03958227)
# Copied: ILSVRC2013_val_00003461.xml (XML)
# Copied: ILSVRC2013_val_00003483.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003483.xml (XML)
# Copied: ILSVRC2013_val_00003495.JPEG (n03337140, n03337140, n03337140)
# Copied: ILSVRC2013_val_00003495.xml (XML)
# Copied: ILSVRC2013_val_00003528.JPEG (n04557648, n04557648, n04557648, n04557648)
# Copied: ILSVRC2013_val_00003528.xml (XML)
# Copied: ILSVRC2013_val_00003570.JPEG (n07753592)
# Copied: ILSVRC2013_val_00003570.xml (XML)
# Copied: ILSVRC2013_val_00003585.JPEG (n07697537, n07697537)
# Copied: ILSVRC2013_val_00003585.xml (XML)
# Copied: ILSVRC2013_val_00003600.JPEG (n02274259)
# Copied: ILSVRC2013_val_00003600.xml (XML)
# Copied: ILSVRC2013_val_00003634.JPEG (n02084071, n02084071)
# Copied: ILSVRC2013_val_00003634.xml (XML)
# Copied: ILSVRC2013_val_00003644.JPEG (n03642806)
# Copied: ILSVRC2013_val_00003644.xml (XML)
# Copied: ILSVRC2013_val_00003646.JPEG (n02206856)
# Copied: ILSVRC2013_val_00003646.xml (XML)
# Copied: ILSVRC2013_val_00003666.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003666.xml (XML)
# Copied: ILSVRC2013_val_00003668.JPEG (n03958227, n03958227)
# Copied: ILSVRC2013_val_00003668.xml (XML)
# Copied: ILSVRC2013_val_00003671.JPEG (n02206856)
# Copied: ILSVRC2013_val_00003671.xml (XML)
# Copied: ILSVRC2013_val_00003685.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003685.xml (XML)
# Copied: ILSVRC2013_val_00003764.JPEG (n04557648)
# Copied: ILSVRC2013_val_00003764.xml (XML)
# Copied: ILSVRC2013_val_00003772.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003772.xml (XML)
# Copied: ILSVRC2013_val_00003797.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003797.xml (XML)
# Copied: ILSVRC2013_val_00003803.JPEG (n07697537, n07697537)
# Copied: ILSVRC2013_val_00003803.xml (XML)
# Copied: ILSVRC2013_val_00003810.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003810.xml (XML)
# Copied: ILSVRC2013_val_00003874.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003874.xml (XML)
# Copied: ILSVRC2013_val_00003890.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003890.xml (XML)
# Copied: ILSVRC2013_val_00003892.JPEG (n03337140, n03337140)
# Copied: ILSVRC2013_val_00003892.xml (XML)
# Copied: ILSVRC2013_val_00003909.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003909.xml (XML)
# Copied: ILSVRC2013_val_00003913.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003913.xml (XML)
# Copied: ILSVRC2013_val_00003952.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003952.xml (XML)
# Copied: ILSVRC2013_val_00003961.JPEG (n07753592)
# Copied: ILSVRC2013_val_00003961.xml (XML)
# Copied: ILSVRC2013_val_00003963.JPEG (n02084071)
# Copied: ILSVRC2013_val_00003963.xml (XML)
# Copied: ILSVRC2013_val_00003977.JPEG (n03337140)
# Copied: ILSVRC2013_val_00003977.xml (XML)
# Copied: ILSVRC2013_val_00004009.JPEG (n02084071)
# Copied: ILSVRC2013_val_00004009.xml (XML)
# Copied: ILSVRC2013_val_00004010.JPEG (n02084071)
# Copied: ILSVRC2013_val_00004010.xml (XML)
# Copied: ILSVRC2013_val_00004017.JPEG (n02084071)
# Copied: ILSVRC2013_val_00004017.xml (XML)
# Copied: ILSVRC2013_val_00004032.JPEG (n02084071)
# Copied: ILSVRC2013_val_00004032.xml (XML)
# Copied: ILSVRC2013_val_00004059.JPEG (n03642806)
# Copied: ILSVRC2013_val_00004059.xml (XML)
# Copied: ILSVRC2013_val_00004083.JPEG (n02815834)
# Copied: ILSVRC2013_val_00004083.xml (XML)
# Copied: ILSVRC2013_val_00004119.JPEG (n03958227, n03958227, n03958227, n03958227, n03958227, n03958227, n03958227)
# Copied: ILSVRC2013_val_00004119.xml (XML)
# Copied: ILSVRC2013_val_00004167.JPEG (n03958227)
# Copied: ILSVRC2013_val_00004167.xml (XML)
# Copied: ILSVRC2013_val_00004176.JPEG (n02274259)
# Copied: ILSVRC2013_val_00004176.xml (XML)
# Copied: ILSVRC2013_val_00004247.JPEG (n03642806)
# Copied: ILSVRC2013_val_00004247.xml (XML)
# Copied: ILSVRC2013_val_00004261.JPEG (n07697537, n07697537)
# Copied: ILSVRC2013_val_00004261.xml (XML)
# Copied: ILSVRC2013_val_00004288.JPEG (n03337140)
# Copied: ILSVRC2013_val_00004288.xml (XML)
# Copied: ILSVRC2013_val_00004311.JPEG (n03642806)
# Copied: ILSVRC2013_val_00004311.xml (XML)
# Copied: ILSVRC2013_val_00004312.JPEG (n02206856)
# Copied: ILSVRC2013_val_00004312.xml (XML)
# Copied: ILSVRC2013_val_00004314.JPEG (n04557648, n04557648, n04557648)
# Copied: ILSVRC2013_val_00004314.xml (XML)
# Copied: ILSVRC2013_val_00004339.JPEG (n04557648)
# Copied: ILSVRC2013_val_00004339.xml (XML)
# Copied: ILSVRC2013_val_00004364.JPEG (n03642806)
# Copied: ILSVRC2013_val_00004364.xml (XML)
# Copied: ILSVRC2013_val_00004373.JPEG (n03958227)
# Copied: ILSVRC2013_val_00004373.xml (XML)
# Copied: ILSVRC2013_val_00004417.JPEG (n03958227)
# Copied: ILSVRC2013_val_00004417.xml (XML)
# Copied: ILSVRC2013_val_00004419.JPEG (n03958227)
# Copied: ILSVRC2013_val_00004419.xml (XML)
# Copied: ILSVRC2013_val_00004443.JPEG (n02084071)
# Copied: ILSVRC2013_val_00004443.xml (XML)
# Copied: ILSVRC2013_val_00004459.JPEG (n07753592)
# Copied: ILSVRC2013_val_00004459.xml (XML)
# Copied: ILSVRC2013_val_00004497.JPEG (n03958227, n03958227)
# Copied: ILSVRC2013_val_00004497.xml (XML)
# Copied: ILSVRC2013_val_00004507.JPEG (n03642806)
# Copied: ILSVRC2013_val_00004507.xml (XML)
# Copied: ILSVRC2013_val_00004509.JPEG (n02084071)
# Copied: ILSVRC2013_val_00004509.xml (XML)
# Copied: ILSVRC2013_val_00004512.JPEG (n03642806)
# Copied: ILSVRC2013_val_00004512.xml (XML)
# Copied: ILSVRC2013_val_00004515.JPEG (n02084071)
# Copied: ILSVRC2013_val_00004515.xml (XML)
# Copied: ILSVRC2013_val_00004521.JPEG (n02084071)
# Copied: ILSVRC2013_val_00004521.xml (XML)
# Copied: ILSVRC2013_val_00004543.JPEG (n03958227)
# Copied: ILSVRC2013_val_00004543.xml (XML)
# Validation dataset filtering complete!
